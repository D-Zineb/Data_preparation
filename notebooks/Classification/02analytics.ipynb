# %%
DATA_PATH = '../../data/Classification/processed/2_preprocessed_df.pkl'

# %% [markdown]
# Importation des libs

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns

# %%
raw_df = pd.read_pickle(DATA_PATH)

# %%
raw_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                                     path  \
# ...

# %%
fig = px.histogram(raw_df, x="dx")
fig.show()

# %%
y = raw_df['dx']
y = [1 if each == 'bkl' or each == "nv" or each == "df" else 0 for each in raw_df['dx']]
y = pd.DataFrame(y)
y.value_counts().plot(kind='bar')
y.value_counts()
# Out:
# 1    7919
# 0    2096
# dtype: int64

# %%
fig = px.histogram(raw_df, x="dx_type")
fig.show()

# %%
fig = px.histogram(raw_df, x="localization")
fig.show()

# %%
fig = px.histogram(raw_df, x="sex")
fig.show()

# %%
fig = px.histogram(raw_df, x="age")
fig.show()

# %%
fig = px.histogram(raw_df, x="dx", color="localization")
fig.show()

# %%
fig = px.histogram(raw_df, x="dx", color="dx_type")
fig.show()

# %%
fig = px.sunburst(raw_df, path=['dx','localization', 'sex'], values=np.ones(10015))
fig.show()

# %%
fig = px.sunburst(raw_df, path=['sex','localization', 'dx'],values=np.ones(10015))
fig.show()

# %%
fig = px.sunburst(raw_df, path=['localization','sex', 'dx'],values=np.ones(10015))
fig.show()
