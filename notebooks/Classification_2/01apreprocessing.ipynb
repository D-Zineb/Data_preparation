# %%
DATA_PATH = '../../data/Classification_2/raw/HAM10000_metadata.csv'
EXPORT_DIR='../../data/Classification_2/processed'
EXPORT_PATH = '../../data/Classification_2/processed/2_preprocessed_df.pkl'

# %%
import pandas as pd
import missingno as ms
import plotly.express as px
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv(DATA_PATH)

# %% [markdown]
# Missing values / Integer

# %%
raw_df.isna().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %%
ms.bar(raw_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# --> Handling missing values

# %%
raw_df['age'].fillna(raw_df['age'].mean(),inplace=True)

# %%
raw_df.isna().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# dtype: int64

# %% [markdown]
# EXPORT DATA

# %%
os.mkdir(EXPORT_DIR)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1276/1714013217.py in <module>
# ----> 1 os.mkdir(EXPORT_DIR)
#
# FileExistsError: [WinError 183] Impossible de créer un fichier déjà existant: '../../data/Classification_2/processed'

# %%
raw_df.to_pickle(EXPORT_PATH)
