# %%
DF_PATH = "../../data/Classification_1/processed/1_preprocessed_df.pkl"

# %%
import pandas as pd 
import numpy as np
import pickle

# %%
df = pd.read_pickle(DF_PATH)

# %%
df
# Out:
#         id  age  education  sex  is_smoking  cigsPerDay    BPMeds  \
# 0        0   64        2.0    1           1         3.0  0.000000
# 1        1   36        4.0    0           0         0.0  0.000000
# 2        2   46        1.0    1           1        10.0  0.000000
# 3        3   50        1.0    0           1        20.0  0.000000
# 4        4   64        1.0    1           1        30.0  0.000000
# ...    ...  ...        ...  ...         ...         ...       ...
# 3385  3385   60        1.0    1           0         0.0  0.000000
# 3386  3386   46        1.0    1           0         0.0  0.000000
# 3387  3387   44        3.0    0           1         3.0  0.000000
# 3388  3388   60        1.0    0           0         0.0  0.029886
# 3389  3389   54        3.0    1           0         0.0  0.000000
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP  \
# 0                   0             0         0    221.0  148.0   85.0
# ...

# %% [markdown]
# Dimensionality reduction

# %%
df=df.drop(['id','is_smoking','sysBP'],axis=1)

# %%
df
# Out:
#       age  education  sex  cigsPerDay    BPMeds  prevalentStroke  \
# 0      64        2.0    1         3.0  0.000000                0
# 1      36        4.0    0         0.0  0.000000                0
# 2      46        1.0    1        10.0  0.000000                0
# 3      50        1.0    0        20.0  0.000000                0
# 4      64        1.0    1        30.0  0.000000                0
# ...   ...        ...  ...         ...       ...              ...
# 3385   60        1.0    1         0.0  0.000000                0
# 3386   46        1.0    1         0.0  0.000000                0
# 3387   44        3.0    0         3.0  0.000000                0
# 3388   60        1.0    0         0.0  0.029886                0
# 3389   54        3.0    1         0.0  0.000000                0
#
#       prevalentHyp  diabetes  totChol  diaBP        BMI  heartRate  glucose  \
# 0                0         0    221.0   85.0  25.794964       90.0     80.0
# ...

# %% [markdown]
# Export data

# %%
df.to_pickle(DF_PATH)
